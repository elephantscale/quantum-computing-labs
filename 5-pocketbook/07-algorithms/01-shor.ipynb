# %% [markdown]
# # Shor algorithm
#
# ## Overview
#
# * Shor
#
# ### Depends On
#
# * 0-setup
#
# ### Run time
#
# 45 min

# %% [markdown]
# ## Using algorithms

# %% [markdown]
# * All algorithms interfaces in Qiskit algorithms follow a consistent pattern.
# * Let's learn about this pattern and the rationale behind it.

# %%
from qiskit.providers.aer import AerSimulator

# %%
aer_sim = AerSimulator()

# %% [markdown]
# Use this simulator and create an instance of Shor algorithm

# %%
from qiskit.algorithms import Shor
# Out:
# /tmp/ipykernel_6512/2145213915.py:1: DeprecationWarning: ``qiskit.algorithms`` has been migrated to an independent package: https://github.com/qiskit-community/qiskit-algorithms. The ``qiskit.algorithms`` import path is deprecated as of qiskit-terra 0.25.0 and will be removed no earlier than 3 months after the release date. Please run ``pip install qiskit_algorithms`` and use ``import qiskit_algorithms`` instead.
#   from qiskit.algorithms import Shor
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from qiskit.algorithms import Shor
#
# ImportError: cannot import name 'Shor' from 'qiskit.algorithms' (/home/mark/anaconda3/envs/Qiskit/lib/python3.9/site-packages/qiskit/algorithms/__init__.py)
